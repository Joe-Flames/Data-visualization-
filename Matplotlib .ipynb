# %%
# %matplotlib inline
import pandas as pd
from matplotlib import pyplot as plt
import math
import numpy as np
import random

# %%
plt.plot([1,2,3,4])

# %% [markdown]
# # Dot Chart

# %%
plt.plot([1,2,3,4],[1,4,9,16],'ro')

# %% [markdown]
# # Sine graph

# %%
t=np.arange(0,2.5,0.1)
y1=map(math.sin,math.pi*t)
y2=map(math.sin,math.pi*t+math.pi/2)
y3=map(math.sin,math.pi*t-math.pi/2)
plt.plot(t,y1,'b--',t,y2,'g',t,y3,'r-.')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [16], in <cell line: 5>()
#       3 y2=map(math.sin,math.pi*t+math.pi/2)
#       4 y3=map(math.sin,math.pi*t-math.pi/2)
# ----> 5 plt.plot(t,y1,'b--',t,y2,'g',t,y3,'r-.')
#
# File /data/user/0/ru.iiec.pydroid3/files/arm-linux-androideabi/lib/python3.9/site-packages/matplotlib/pyplot.py:3019, in plot(scalex, scaley, data, *args, **kwargs)
#    3017 @_copy_docstring_and_deprecators(Axes.plot)
#    3018 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 3019     return gca().plot(
#    3020         *args, scalex=scalex, scaley=scaley,
#    3021         **({"data": data} if data is not None else {}), **kwargs)
#
# File /data/user/0/ru.iiec.pydroid3/files/arm-linux-androideabi/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1605, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1363 """
#    1364 Plot y versus x as lines and/or markers.
#    1365
#    (...)
#    1602 (``'green'``) or hex strings (``'#008000'``).
#    1603 """
#    1604 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1605 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606 for line in lines:
#    1607     self.add_line(line)
#
# File /data/user/0/ru.iiec.pydroid3/files/arm-linux-androideabi/lib/python3.9/site-packages/matplotlib/axes/_base.py:315, in _process_plot_var_args.__call__(self, data, *args, **kwargs)
#     313     this += args[0],
#     314     args = args[1:]
# --> 315 yield from self._plot_args(this, kwargs)
#
# File /data/user/0/ru.iiec.pydroid3/files/arm-linux-androideabi/lib/python3.9/site-packages/matplotlib/axes/_base.py:498, in _process_plot_var_args._plot_args(self, tup, kwargs, return_kwargs)
#     496     self.axes.xaxis.update_units(x)
#     497 if self.axes.yaxis is not None:
# --> 498     self.axes.yaxis.update_units(y)
#     500 if x.shape[0] != y.shape[0]:
#     501     raise ValueError(f"x and y must have same first dimension, but "
#     502                      f"have shapes {x.shape} and {y.shape}")
#
# File /data/user/0/ru.iiec.pydroid3/files/arm-linux-androideabi/lib/python3.9/site-packages/matplotlib/axis.py:1442, in Axis.update_units(self, data)
#    1436 def update_units(self, data):
#    1437     """
#    1438     Introspect *data* for units converter and update the
#    1439     axis.converter instance if necessary. Return *True*
#    1440     if *data* is registered for unit conversion.
#    1441     """
# -> 1442     converter = munits.registry.get_converter(data)
#    1443     if converter is None:
#    1444         return False
#
# File /data/user/0/ru.iiec.pydroid3/files/arm-linux-androideabi/lib/python3.9/site-packages/matplotlib/units.py:217, in Registry.get_converter(self, x)
#     213 else:
#     214     # ... and avoid infinite recursion for pathological iterables for
#     215     # which indexing returns instances of the same iterable class.
#     216     if type(first) is not type(x):
# --> 217         return self.get_converter(first)
#     218 return None
#
# File /data/user/0/ru.iiec.pydroid3/files/arm-linux-androideabi/lib/python3.9/site-packages/matplotlib/units.py:210, in Registry.get_converter(self, x)
#     208         pass
#     209 try:  # If cache lookup fails, look up based on first element...
# --> 210     first = cbook.safe_first_element(x)
#     211 except (TypeError, StopIteration):
#     212     pass
#
# File /data/user/0/ru.iiec.pydroid3/files/arm-linux-androideabi/lib/python3.9/site-packages/matplotlib/cbook/__init__.py:1713, in safe_first_element(obj)
#    1711     except TypeError:
#    1712         pass
# -> 1713     raise RuntimeError("matplotlib does not support generators "
#    1714                        "as input")
#    1715 return next(iter(obj))
#
# RuntimeError: matplotlib does not support generators as input

# %%
plt.axis([0,5,0,20])
plt.title('My first plot',fontsize=20,fontname='Times New Roman')
plt.xlabel('Counting',color='gray')
plt.ylabel('Square values',color='gray')
plt.text(1,1.5,'First')
plt.text(2,4.5,'Second')
plt.text(3,9.5,'Third')
plt.text(4,16.5,'Fourth')
plt.text(1.1,12,'$y = x^2$',fontsize=20,bbox={'facecolor':'yellow','alpha':0.2})
plt.grid(True)
plt.plot([1,2,3,4],[1,4,9,16],'ro')
plt.plot([1,2,3,4],[0.8,3.5,8,15],'g^')
plt.plot([1,2,3,4],[0.5,2.5,4,12],'b*')
plt.legend(['First series','Second series','Third series'],loc=2)
plt.show()

# %%
import matplotlib.pyplot as plt
labels = ['Nokia','Samsung','Apple','Lumia']
values = [10,30,45,15]
colors = ['yellow','green','red','blue']
explode = [0.3,0,0,0]
plt.title('A Pie Chart')
plt.pie(values,labels=labels,colors=colors,explode=explode,startangle=180)
plt.axis('equal')
# Out:
# (-1.4003625034945653,
#  1.130639575385504,
#  -1.1007797083302826,
#  1.1163737124158366)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
data = {'series1':[1,3,4,3,5],
'series2':[2,4,5,2,4],
'series3':[3,2,3,1,3]}
df = pd.DataFrame(data)
df.plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
import matplotlib.pyplot as plt
import numpy as np
dx = 0.01; dy = 0.01
x = np.arange(-2.0,2.0,dx)
y = np.arange(-2.0,2.0,dy)
X,Y = np.meshgrid(x,y)
C = plt.contour(X,Y,f(X,Y),8,colors='black')
plt.contourf(X,Y,f(X,Y),8,cmap=plt.cm.hot)
plt.clabel(C, inline=1, fontsize=10)
plt.colorbar()

# %%
import matplotlib.pyplot as plt
import numpy as np
dx = 0.01; dy = 0.01
x = np.arange(-2.0,2.0,dx)
y = np.arange(-2.0,2.0,dy)
X,Y = np.meshgrid(x,y)
def f(x,y):return (1 - y**5 + x**5)*np.exp(-x**2-y**2)
C = plt.contour(X,Y,f(X,Y),8,colors='black')
plt.contourf(X,Y,f(X,Y),8,cmap=plt.cm.hot)
plt.clabel(C, inline=1, fontsize=10)
plt.colorbar()

# %%
import matplotlib.pyplot as plt
import numpy as np
dx = 0.01; dy = 0.01
x = np.arange(-2.0,2.0,dx)
y = np.arange(-2.0,2.0,dy)
X,Y = np.meshgrid(x,y)
def f(x,y):import matplotlib.pyplot as plt
import numpy as np
dx = 0.01; dy = 0.01
x = np.arange(-2.0,2.0,dx)
y = np.arange(-2.0,2.0,dy)
X,Y = np.meshgrid(x,y)
def f(x,y):return (1 - y**5 + x**5)*np.exp(-x**2-y**2)
C = plt.contour(X,Y,f(X,Y),8,colors='black')
plt.contourf(X,Y,f(X,Y),8)
plt.clabel(C, inline=1, fontsize=10)
